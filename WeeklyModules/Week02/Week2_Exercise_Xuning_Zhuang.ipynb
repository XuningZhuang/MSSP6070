# %% [markdown]
# <a href="https://colab.research.google.com/github/XuningZhuang/MSSP6070/blob/main/WeeklyModules/Week02/Week2_Exercise_Xuning_Zhuang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 Assignment

# %%
#2.
spam = [2, 4, 6, 8, 10]
spam[2] = 'hello'

spam
# Out:
# [2, 4, 'hello', 8, 10]

# %%
#3.
letters = ['a', 'b', 'c', 'd']
letters[int(int('3'*2)//11)]
# '3'*2 becomes '33', 33//11 = 3, so letters[3] is the letter d
print(letters[int(int('3'*2)//11)])

letters[-1]
# the negative signal means we need to count backword, so that -1 is the last item in the list, which is the letter d
print(letters[-1])

letters[:2]
# it means from the beginning letter to the third letter, but the third letter is not included, so it is the letter a and b
print(letters[:2] )
# Out:
# d
# d
# ['a', 'b']

# %%
#4.
# get the tuple form of the value of a list
list0 = ['a', 'b', 'c', 'd']
tuple0 = tuple(list0)
print(tuple0)

# get the lists from a tuple
list1 = list(tuple0)
print(list1)
# Out:
# ('a', 'b', 'c', 'd')
# ['a', 'b', 'c', 'd']

# %%
#5.
spam = ['apples', 'bananas', 'tofu', 'cats']
def comma_code(spam):
    return ', '.join(spam[:-1]) + ', and ' + spam[-1]

comma_code(spam)
# Out:
# 'apples, bananas, tofu, and cats'
